# %%
import pandas as pd

# %%
df = pd.read_csv('housingData.csv')

# %%
print(df.head())
# Out:
#    RegionName           City State          Metro     CountyName  SizeRank  \
# 0       10023       New York    NY       New York       New York         1
# 1       60614        Chicago    IL        Chicago           Cook         2
# 2       10002       New York    NY       New York       New York         3
# 3       94109  San Francisco    CA  San Francisco  San Francisco         4
# 4       11375       New York    NY       New York         Queens         5
#
#    2010-01  2010-02  2010-03  2010-04     ...           2016-12      2017-01  \
# 0      NaN      NaN      NaN      NaN     ...       1942.457079  1944.164364
# 1      NaN      NaN      NaN      NaN     ...        389.933333   398.787141
# 2      NaN      NaN      NaN      NaN     ...       2010.594079  2013.888889
# 3      NaN      NaN      NaN      NaN     ...       1114.761669  1130.438822
# 4      NaN      NaN      NaN      NaN     ...        407.142857   407.435065
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates()
# Out:
#       RegionName                 City State                           Metro  \
# 8          37211            Nashville    TN                       Nashville
# 9          37013            Nashville    TN                       Nashville
# 10         60618              Chicago    IL                         Chicago
# 15         90046          Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 17         20009           Washington    DC                      Washington
# 19         63376         Saint Peters    MO                       St. Louis
# 21         60629              Chicago    IL                         Chicago
# 23         23464       Virginia Beach    VA                  Virginia Beach
# 24          7030              Hoboken    NJ                        New York
# 25         28277            Charlotte    NC                       Charlotte
# 28         33160    Sunny Isles Beach    FL           Miami-Fort Lauderdale
# ...

# %%
print(df.head())
# Out:
#     RegionName         City State                           Metro  \
# 8        37211    Nashville    TN                       Nashville
# 9        37013    Nashville    TN                       Nashville
# 10       60618      Chicago    IL                         Chicago
# 15       90046  Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 17       20009   Washington    DC                      Washington
#
#               CountyName  SizeRank     2010-01     2010-02     2010-03  \
# 8               Davidson         9  106.102388  105.430923  103.379310
# 9               Davidson        10   83.384853   85.882353   83.624655
# 10                  Cook        11  236.500000  237.759715  237.692308
# 15           Los Angeles        16  565.123789  550.314465  544.029851
# 17  District of Columbia        18  501.404213  507.433719  527.944112
#
#        2010-04     ...         2016-12     2017-01     2017-02     2017-03  \
# ...

# %%
df.tail()
# Out:
#       RegionName                City State          Metro  CountyName  \
# 1505       28512      Atlantic Beach    NC  Morehead City    Carteret
# 1509       97394            Waldport    OR        Newport     Lincoln
# 1520       28746           Lake Lure    NC    Forest City  Rutherford
# 1523       85933           Overgaard    AZ       Show Low      Navajo
# 1530       78597  South Padre Island    TX    Brownsville     Cameron
#
#       SizeRank     2010-01     2010-02     2010-03     2010-04     ...      \
# 1505      1506  281.371179  292.560976  280.637255  278.692560     ...
# 1509      1510  203.705693  209.421112  202.255639  204.166667     ...
# 1520      1521  190.000000  192.902615  190.000000  194.743935     ...
# 1523      1524  136.317136  135.866901  135.254917  131.719551     ...
# 1530      1531  218.940248  219.435028  225.000000  219.795792     ...
#
#          2016-12     2017-01     2017-02     2017-03     2017-04     2017-05  \
# ...

# %%
df.set_index('City', inplace=True)

# %%
df.to_csv('newHsngData.csv')

# %%
pd.read_csv('newHsngData.csv')
# Out:
#                     City  RegionName State                           Metro  \
# 0              Nashville       37211    TN                       Nashville
# 1              Nashville       37013    TN                       Nashville
# 2                Chicago       60618    IL                         Chicago
# 3            Los Angeles       90046    CA  Los Angeles-Long Beach-Anaheim
# 4             Washington       20009    DC                      Washington
# 5           Saint Peters       63376    MO                       St. Louis
# 6                Chicago       60629    IL                         Chicago
# 7         Virginia Beach       23464    VA                  Virginia Beach
# 8                Hoboken        7030    NJ                        New York
# 9              Charlotte       28277    NC                       Charlotte
# 10     Sunny Isles Beach       33160    FL           Miami-Fort Lauderdale
# ...

# %%
df.head()
# Out:
#              RegionName State                           Metro  \
# City
# Nashville         37211    TN                       Nashville
# Nashville         37013    TN                       Nashville
# Chicago           60618    IL                         Chicago
# Los Angeles       90046    CA  Los Angeles-Long Beach-Anaheim
# Washington        20009    DC                      Washington
#
#                        CountyName  SizeRank     2010-01     2010-02  \
# City
# Nashville                Davidson         9  106.102388  105.430923
# Nashville                Davidson        10   83.384853   85.882353
# Chicago                      Cook        11  236.500000  237.759715
# Los Angeles           Los Angeles        16  565.123789  550.314465
# Washington   District of Columbia        18  501.404213  507.433719
#
#                 2010-03     2010-04     2010-05     ...         2016-12  \
# City                                                ...
# ...

# %%
df.to_html('newhtmlHousingData.html')

# %%
df_html = pd.read_html('newhtmlHousingData.html')

# %%
df_New = pd.read_csv('housingData.csv', names=['RegionName','City'])
df.head()
# Out:
#              RegionName State                           Metro  \
# City
# Nashville         37211    TN                       Nashville
# Nashville         37013    TN                       Nashville
# Chicago           60618    IL                         Chicago
# Los Angeles       90046    CA  Los Angeles-Long Beach-Anaheim
# Washington        20009    DC                      Washington
#
#                        CountyName  SizeRank     2010-01     2010-02  \
# City
# Nashville                Davidson         9  106.102388  105.430923
# Nashville                Davidson        10   83.384853   85.882353
# Chicago                      Cook        11  236.500000  237.759715
# Los Angeles           Los Angeles        16  565.123789  550.314465
# Washington   District of Columbia        18  501.404213  507.433719
#
#                 2010-03     2010-04     2010-05     ...         2016-12  \
# City                                                ...
# ...

# %%
df.rename(columns={'City':'Town'},inplace=True)
df.head()
# Out:
#              RegionName State                           Metro  \
# City
# Nashville         37211    TN                       Nashville
# Nashville         37013    TN                       Nashville
# Chicago           60618    IL                         Chicago
# Los Angeles       90046    CA  Los Angeles-Long Beach-Anaheim
# Washington        20009    DC                      Washington
#
#                        CountyName  SizeRank     2010-01     2010-02  \
# City
# Nashville                Davidson         9  106.102388  105.430923
# Nashville                Davidson        10   83.384853   85.882353
# Chicago                      Cook        11  236.500000  237.759715
# Los Angeles           Los Angeles        16  565.123789  550.314465
# Washington   District of Columbia        18  501.404213  507.433719
#
#                 2010-03     2010-04     2010-05     ...         2016-12  \
# City                                                ...
# ...

# %%
dfNew = pd.read_csv('ZILLOW-Z77006_ZRIFAH.csv')

# %%
dfNew.head()
# Out:
#          Date  Value
# 0  2018-08-31  1.392
# 1  2018-07-31  1.394
# 2  2018-06-30  1.396
# 3  2018-05-31  1.396
# 4  2018-04-30  1.396

# %%
dfNew.set_index('Date', inplace=True)

# %%
dfNew.to_html('ZillowHTML.html')

# %%
dfNew1 = pd.read_html('ZillowHTML.html')
dfNew1.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-b381729638f0> in <module>()
#       1 dfNew1 = pd.read_html('ZillowHTML.html')
# ----> 2 dfNew1.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
dfNew.rename(columns= {'Value':'Values'})
# Out:
#             Values
# Date
# 2018-08-31   1.392
# 2018-07-31   1.394
# 2018-06-30   1.396
# 2018-05-31   1.396
# 2018-04-30   1.396
# 2018-03-31   1.396
# 2018-02-28   1.394
# 2018-01-31   1.394
# 2017-12-31   1.394
# 2017-11-30   1.392
# 2017-10-31   1.388
# 2017-09-30   1.384
# 2017-08-31   1.380
# 2017-07-31   1.382
# 2017-06-30   1.382
# 2017-05-31   1.386
# 2017-04-30   1.390
# 2017-03-31   1.396
# 2017-02-28   1.404
# 2017-01-31   1.414
# 2016-12-31   1.430
# 2016-11-30   1.446
# 2016-10-31   1.460
# 2016-09-30   1.476
# 2016-08-31   1.490
# 2016-07-31   1.502
# 2016-06-30   1.502
# 2016-05-31   1.500
# 2016-04-30   1.488
# 2016-03-31   1.514
# ...            ...
# 2013-04-30   1.282
# 2013-03-31   1.272
# 2013-02-28   1.260
# 2013-01-31   1.248
# 2012-12-31   1.234
# 2012-11-30   1.224
# 2012-10-31   1.220
# 2012-09-30   1.216
# 2012-08-31   1.210
# 2012-07-31   1.204
# 2012-06-30   1.196
# 2012-05-31   1.188
# 2012-04-30   1.182
# 2012-03-31   1.178
# 2012-02-29   1.178
# ...
